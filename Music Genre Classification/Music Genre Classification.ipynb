# %% [markdown]
# # Music Genre Classification

# %% [markdown]
# ### Packages

# %%
import os
import cv2
from tensorflow import keras
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import time
import sklearn
import tensorflow as tf
import pandas as pd
import itertools

from tensorflow.keras.models import (Model, Sequential)
from tensorflow.keras.layers import (Input, Add, Conv2D, MaxPooling2D, AveragePooling2D,
                                     GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Activation, Dropout, 
                                     Flatten, BatchNormalization, Concatenate)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, ConfusionMatrixDisplay)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import (GridSearchCV, train_test_split)

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.neighbors import KNeighborsClassifier
import lightgbm as lgbm
from sklearn.preprocessing import OneHotEncoder
import joblib

# %% [markdown]
# #### Global Variables

# %%
GTZAN = {'nGenres': 10, 'genres': ['blues', 'classical', 'country', 'disco', 'hiphop', 
                                   'jazz', 'metal', 'pop', 'reggae', 'rock']}
EXTENDED_BALLROOM = {'nGenres': 9, 'genres': ['chacha', 'foxtrot', 'jive', 'quickstep', 'rumba',
                                              'samba', 'tango', 'viennesewaltz', 'waltz']}
FEATURES = ('stft', 'mfcc', 'melspectrogram', 'fouriertempogram')
RNG_STATE = 422
TEST_SIZE = 0.2
EPOCHS = 50
BATCH_SIZE = 64

# make model csv file to save stats
MODEL_COLS = ["Model Name", "Method", "Dataset", "Feature", "Split", "Test Accuracy", "Test Loss",
                                     "Train Accuracy", "Train Loss", "Best Epoch", "Validation Accuracy",
                                     "Validation Loss", "Training Accuracy", "Training Loss"]
MODEL_STATS = pd.DataFrame(columns = MODEL_COLS)
if not os.path.exists('models/models.csv'): # if not already made
    print("Created models.csv")
    MODEL_STATS.to_csv(r'models/models.csv', index = False)

# %% [markdown]
# ### Helper Methods

# %%
def getFeatures(dataset, feature, split):
    # LOADING
    X = np.load(os.path.join(os.getcwd(), "datasets", dataset, "features", f"{feature}{split}-X.npy"))
    Y = np.load(os.path.join(os.getcwd(), "datasets", dataset, "features", f"{feature}{split}-Y.npy"))
    #SPLITTING
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = TEST_SIZE, random_state = RNG_STATE, 
                                                        stratify = Y)
    
    return (X_train, X_test, Y_train, Y_test)

# %%
def plot_graph(history, title, download = True):
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title(f'{title} Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc = 'upper left')
    if download:
        plt.savefig(f'models/graphs/{name}-Accuracy.png')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{title} Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc = 'upper left')
    if download:
        plt.savefig(f'models/graphs/{name}-Loss.png')
    plt.show()

# %%
def cnf_matrix(cm, labels, name = None):
    plt.figure(figsize=(11,11))
    
    norm_cm = cm / cm.sum(1)
    plt.imshow(norm_cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.xticks(list(range(len(labels))), labels)
    plt.yticks(list(range(len(labels))), labels)
    plt.title('Confusion matrix')
    plt.xlabel('Predicted genre')
    plt.ylabel('True genre')
    thresh = norm_cm.max() / 2.0
    for i, j in itertools.product(range(norm_cm.shape[0]), range(norm_cm.shape[1])):
        plt.text(j, i, '{:.2g}'.format(norm_cm[i, j]),
                 horizontalalignment="center",
                 color="white" if norm_cm[i, j] > thresh else "black")
    
    if name:
        plt.savefig(f'{name}-ConfusionMatrix.png', dpi = 600)
    plt.show()

# %%
def get_res(history, epoch):
    h = history.history
    train_acc = h['categorical_accuracy'][epoch - 1]
    val_acc = h['val_categorical_accuracy'][epoch - 1]
    train_loss = h['loss'][epoch - 1]
    val_loss = h['val_loss'][epoch - 1]
    #print(train_acc, val_acc, train_loss, val_loss)
    
    return train_acc, train_loss, val_acc, val_loss

# %%
def get_model(mod, data, feature, split):
    models_path = os.path.join(os.getcwd(), 'models')
    for file in os.listdir(models_path):
        if file.endswith('_'.join([mod, feature.upper(), data.upper(), str(split)]) + '.h5'):
            model = keras.models.load_model(os.path.join(models_path, file))
            break
    return model

# %% [markdown]
# # Processing
#
# Librosa for feature extraction of audio files\
# STFT | MFCC | Melspectrogram | Fourier Tempogram
#
# GTZAN (10 Genres)\
# Extended Ballroom (9 Genres - removed 4 for having less than 100 samples)

# %%
def process(dataset, feature, time_split, verbose = False, save = False):
    N_FFT = 2048
    HOP_LENGTH = 1024
    N_MELS = 64
    N_MFCC = 13
    
    processed = []
    processed_genres = []
    
    feature = feature.lower()
    aud_path = os.path.join(os.getcwd(), "datasets", dataset, "audio")
    if not os.path.exists(aud_path):
        print("Dataset not found:", aud_path)
        return
        
    features = ("stft", "melspectrogram", "mfcc", "fouriertempogram")
    TOTAL_GENRES = len(os.listdir(aud_path))

    if feature not in features:
        print(f"{feature} not available for extraction")
        return
    
    feat_path = os.path.join(os.getcwd(), "datasets", dataset, "features")
    os.path.isdir(feat_path) or os.makedirs(feat_path)
    
    currentGenre = 0
    for folder in os.listdir(aud_path):
        folder_path = os.path.join(aud_path, folder)
        for audio in os.listdir(folder_path):  
            audio_path = os.path.join(folder_path, audio)
            y, sr = librosa.load(audio_path) # can user offset and duration for 5 second intervals
            if feature == "stft":
                feat = np.abs(librosa.stft(y, hop_length = HOP_LENGTH, n_fft = N_FFT))
            elif feature == "mfcc":
                feat = librosa.feature.mfcc(y = y, sr = sr, hop_length = HOP_LENGTH, 
                                                      n_fft = N_FFT)
            elif feature == "melspectrogram":
                feat = librosa.feature.melspectrogram(y = y, sr = sr, n_mels = N_MELS, n_fft = N_FFT,
                                                     hop_length = HOP_LENGTH)
            elif feature == "fouriertempogram":
                oenv = librosa.onset.onset_strength(y = y, sr = sr, hop_length = HOP_LENGTH)
                feat = librosa.feature.fourier_tempogram(onset_envelope = oenv, sr = sr, hop_length = HOP_LENGTH)
                #feat = librosa.feature.tempogram(onset_envelope = oenv, sr = sr, hop_length = HOP_LENGTH)
            feat = librosa.power_to_db(feat ** 2) # feat ** 2 for amplitude to db
            #if len(feat[0]) != 647:
            #    print(len(feat[0]))
            #print(feat.shape)
            #print(feat[:2, :512].shape)
            #librosa.display.specshow(feat[:, :], sr=sr, hop_length = HOP_LENGTH, x_axis = 'time', y_axis = 'mel')
            #print(feat.shape)
            
            # max is (x, 647) or (x, 648) -- imma treat max as 640 -- can be //10,8,5,4,2 -> 3, 3.75, 6, 7.5, 15
            out = feat[:, :640]

            # split into segments -- 3, 3.75, 6, 7.5, 15 seconds
            out_split = np.hsplit(out, time_split)
            for split in out_split:
                #print(split.shape)
                processed.append(split)
                # one hot encoding
                processed_genres.append([1 if i == currentGenre else 0 for i in range(TOTAL_GENRES)])
                #librosa.display.specshow(split[:, :], sr=sr, hop_length = HOP_LENGTH, x_axis = 'time', y_axis = 'mel')
            #print(len(out_split))
            #librosa.display.specshow(out[:, :], sr=sr, hop_length = HOP_LENGTH)
        currentGenre += 1
        if verbose:
            print(folder, "complete;", feature, processed[0].shape)
    
    X = np.array(processed)
    Y = np.array(processed_genres)
    
    
    if save:
        #np.save(os.path.join(feat_path, f"{feature + str(time_split)}-X.npy"), X)
        #np.save(os.path.join(feat_path, f"{feature + str(time_split)}-Y.npy"), Y)
        pass
    
    return X, Y

# %% [markdown]
# ### Run to extract features if have not done so already
#
# Extracting features from Extended Ballroom taks a while, 10x+ longer than GTZAN

# %%
features = ("stft", "melspectrogram", "mfcc", "fouriertempogram",)
datasets = ("GTZAN", "Extended Ballroom",)
splits = (10, 8, 5, 4, 2, 1)
splits = (1, )
for dataset in datasets:
    print("Processing", dataset, "with total genres of", 
              len(os.listdir(os.path.join(os.getcwd(), "datasets", dataset, "audio"))))
    for feature in features:
        start = time.perf_counter()
        for split in splits:
            process(dataset, feature, split, verbose = True, save = True)
        print(f"\t{feature} with splits", str(splits), "took", time.perf_counter() - start, "seconds")

# %% [markdown]
# ## CNN
#
# ![CNN](images/CNN.png)

# %% [markdown]
# ### STFT (1025, 640)
#
# ![STFT](images/STFT.png)

# %%
def conv_block(x, n_filters, kernel_size, conv_strides, pool_strides, pool_size):
    x = Conv2D(n_filters, kernel_size, strides = conv_strides, padding='same')(x)
    x = BatchNormalization()(x) # should do this
    x = Activation('relu')(x)
    
    # reduce overfitting by oversampling? extracts most prominent features
    x = MaxPooling2D(pool_size=pool_size, strides=pool_size)(x)
    x = Dropout(0.25)(x) # to reduce overfitting # shouldnt do this when its first level
    return x

# %%
def CNN(input_shape, num_genres, name):
    inpt = Input(shape=input_shape)
    
    x = conv_block(inpt, n_filters = 16, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = conv_block(x, n_filters = 32, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = conv_block(x, n_filters = 64, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = conv_block(x, n_filters = 128, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (4, 4), pool_size = (4, 4))
    
    x = conv_block(x, n_filters = 64, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', 
              kernel_regularizer = tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.25)(x)
    predictions = Dense(num_genres, 
                        activation='softmax', 
                        kernel_regularizer = tf.keras.regularizers.l2(0.02))(x)
    
    model = Model(inputs=inpt, outputs=predictions, name = name) # can add name
    return model

# %% [markdown]
# #### GTZAN

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split = 10
mod = 'CNN'
feat = 'STFT'
dat = 'GTZAN'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures(dat, feat, split)
#print(X_train.shape)
# Model
m = CNN(X_train.shape[1:] + (1,), 10, name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# Model: "1851_CNN_STFT_GTZAN_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1025, 64, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1025, 64, 16)      160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1025, 64, 16)      64
# _________________________________________________________________
# activation (Activation)      (None, 1025, 64, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 32, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 512, 32, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 32, 32)       4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512, 32, 32)       128
# _________________________________________________________________
# activation_1 (Activation)    (None, 512, 32, 32)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 16, 32)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256, 16, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 16, 64)       18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 16, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 16, 64)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 8, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 8, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 8, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 8, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128, 8, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 2, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 2, 128)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 2, 64)         73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 2, 64)         256
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 2, 64)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 1, 64)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 1, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 437,130
# Trainable params: 436,522
# Non-trainable params: 608
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name) # should save the graphs as well

# %%
best_epoch = 49
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Extended Ballroom

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split =10
mod = 'CNN'
feat = 'STFT'
dat = 'ExtendedBallroom'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures("EXTENDED BALLROOM", feat, split)
# Model
m = CNN(X_train.shape[1:] + (1,), EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# Model: "9967_CNN_STFT_EXTENDEDBALLROOM_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 1025, 64, 1)]     0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1025, 64, 16)      160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1025, 64, 16)      64
# _________________________________________________________________
# activation_13 (Activation)   (None, 1025, 64, 16)      0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 512, 32, 16)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512, 32, 16)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 512, 32, 32)       4640
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512, 32, 32)       128
# _________________________________________________________________
# activation_14 (Activation)   (None, 512, 32, 32)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 256, 16, 32)       0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 256, 16, 32)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 256, 16, 64)       18496
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256, 16, 64)       256
# _________________________________________________________________
# activation_15 (Activation)   (None, 256, 16, 64)       0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 128, 8, 64)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128, 8, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 128, 8, 128)       73856
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128, 8, 128)       512
# _________________________________________________________________
# activation_16 (Activation)   (None, 128, 8, 128)       0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 32, 2, 128)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 32, 2, 128)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 2, 64)         73792
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 32, 2, 64)         256
# _________________________________________________________________
# activation_17 (Activation)   (None, 32, 2, 64)         0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 16, 1, 64)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 16, 1, 64)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 2313
# =================================================================
# Total params: 436,873
# Trainable params: 436,265
# Non-trainable params: 608
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 48
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ### MFCC (20, 640)
#
# ![MFCC](images/MFCC.png)

# %%
def MFCC_block(x, n_filters, kernel_size, conv_strides, pool_strides, pool_size, dropout = None):
    x = Conv2D(n_filters, kernel_size, strides = conv_strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # reduce overfitting by oversampling? extracts most prominent features
    x = MaxPooling2D(pool_size=pool_size, strides=pool_size)(x)
    if dropout:
        x = Dropout(dropout)(x) # to reduce overfitting # shouldnt do this when its first level
    return x

# %%
def MFCC_CNN(input_shape, num_genres, name):
    inpt = Input(shape=input_shape)
    
    x = MFCC_block(inpt, n_filters = 32, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2), dropout = 0.25)
    
    x = MFCC_block(x, n_filters = 64, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2), dropout = 0.25)
    
    x = MFCC_block(x, n_filters = 128, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2), dropout = 0.25)
    
    x = MFCC_block(x, n_filters = 64, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2), dropout = 0.25)
    
    x = Flatten()(x)
    x = Dropout(0.25)(x)
    x = Dense(256, activation='relu', 
              kernel_regularizer = tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.25)(x)
    predictions = Dense(num_genres, 
                        activation='softmax', 
                        kernel_regularizer = tf.keras.regularizers.l2(0.02))(x)
    
    model = Model(inputs=inpt, outputs=predictions, name = name)
    return model

# %% [markdown]
# #### GTZAN

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split = 10
mod = 'CNN'
feat = 'MFCC'
dat = 'GTZAN'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures(dat, feat, split)
#print(X_train.shape)
plt.imshow(X_train[1])
# Model
m = MFCC_CNN(X_train.shape[1:] + (1,), 10, name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# Model: "9346_CNN_MFCC_GTZAN_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 20, 64, 1)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 64, 32)        320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 20, 64, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 20, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 32, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 10, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 10, 32, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 10, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 16, 64)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 16, 64)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 16, 128)        73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 16, 128)        512
# _________________________________________________________________
# activation_7 (Activation)    (None, 5, 16, 128)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 8, 128)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 8, 64)          73792
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2, 8, 64)          256
# _________________________________________________________________
# activation_8 (Activation)    (None, 2, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 235,978
# Trainable params: 235,402
# Non-trainable params: 576
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 74
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Extended Ballroom

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split = 10
mod = 'CNN'
feat = 'MFCC'
dat = 'ExtendedBallroom'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures("EXTENDED BALLROOM", "mfcc", split)
#print(X_train.shape)
plt.imshow(X_train[1])
# Model
m = MFCC_CNN(X_train.shape[1:] + (1,), EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# Model: "2660_CNN_MFCC_EXTENDEDBALLROOM_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 20, 64, 1)]       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 20, 64, 32)        320
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 20, 64, 32)        128
# _________________________________________________________________
# activation_18 (Activation)   (None, 20, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 10, 32, 32)        0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 10, 32, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 10, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 10, 32, 64)        256
# _________________________________________________________________
# activation_19 (Activation)   (None, 10, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 5, 16, 64)         0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 5, 16, 64)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 5, 16, 128)        73856
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 5, 16, 128)        512
# _________________________________________________________________
# activation_20 (Activation)   (None, 5, 16, 128)        0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 2, 8, 128)         0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 2, 8, 128)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 2, 8, 64)          73792
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 8, 64)          256
# _________________________________________________________________
# activation_21 (Activation)   (None, 2, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 1, 4, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 9)                 2313
# =================================================================
# Total params: 235,721
# Trainable params: 235,145
# Non-trainable params: 576
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 54
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ### Melspectrogram (64, 640)
#
# ![MELSPECTROGRAM](images/MELSPECTROGRAM.png)

# %%
def mel_block(x, n_filters, kernel_size, conv_strides, pool_strides, pool_size):
    x = Conv2D(n_filters, kernel_size, strides = conv_strides, padding='same')(x)
    #x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # reduce overfitting by oversampling? extracts most prominent features
    x = MaxPooling2D(pool_size=pool_size, strides=pool_size)(x)
    x = Dropout(0.25)(x) # to reduce overfitting # shouldnt do this when its first level
    return x

# %%
def MEL_CNN(input_shape, num_genres, name):
    inpt = Input(shape=input_shape)
    
    x = mel_block(inpt, n_filters = 16, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = mel_block(x, n_filters = 32, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = mel_block(x, n_filters = 64, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (2, 2), pool_size = (2, 2))
    
    x = mel_block(x, n_filters = 128, kernel_size = (3, 3), 
                   conv_strides = (1, 1), pool_strides = (4, 4), pool_size = (4, 4))
    
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', 
              kernel_regularizer = tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.25)(x)
    
    predictions = Dense(num_genres, 
                        activation='softmax', 
                        kernel_regularizer = tf.keras.regularizers.l2(0.02))(x)
    
    model = Model(inputs=inpt, outputs=predictions, name = name)
    return model

# %% [markdown]
# #### GTZAN

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split = 10
mod = 'CNN'
feat = 'MELSPECTROGRAM'
dat = 'GTZAN'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures(dat, feat, split)
#print(X_train.shape)
plt.imshow(X_train[1])
# Model
m = MEL_CNN(X_train.shape[1:] + (1,), 10, name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# Model: "7083_CNN_MELSPECTROGRAM_GTZAN_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# activation_9 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 32)        4640
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_12 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 231,050
# Trainable params: 231,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 98
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Extended Ballroom

# %%
# Get Features
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
split = 10
mod = 'CNN'
feat = 'MELSPECTROGRAM'
dat = 'ExtendedBallroom'
name = '_'.join([x.upper() for x in [str(uid), mod, feat,dat, str(split)]])
X_train, X_test, Y_train, Y_test = getFeatures("Extended Ballroom", feat, split)
print(X_train.shape)
plt.imshow(X_train[1])
# Model
m = MEL_CNN(X_train.shape[1:] + (1,), EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()
# Out:
# (31936, 64, 64)
# Model: "1905_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 64, 64, 16)        160
# _________________________________________________________________
# activation_22 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 32, 32, 32)        4640
# _________________________________________________________________
# activation_23 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_24 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_25 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 9)                 2313
# =================================================================
# Total params: 230,793
# Trainable params: 230,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit(X_train, Y_train, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 75
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate(X_train, Y_train)
print("Loss:", train[0])
print("Train Accuracy:", train[1])

test = m.evaluate(X_test, Y_test)
print("Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, feat, split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# # Base Results
#
# In the results below, Train Accuracy and Training Accuracy are different. Training Accuracy is the training accuracy from the resulting best epoch, while the Train Accuracy is basically the overall train accuracy of the model.

# %%
MODELS_PATH = os.path.join(os.getcwd(), 'models', 'models.csv')
MODELS = pd.read_csv(MODELS_PATH).set_index("Model Name")
MODELS = MODELS.sort_values('Test Accuracy', ascending = False)
# only base results -- no double inputs and classical
MODELS = MODELS[MODELS['Feature'].isin(['STFT', 'MFCC', 'MELSPECTROGRAM'])]
MODELS = MODELS[MODELS['Method'] == 'CNN']
MODELS
# Out:
#                                             Method           Dataset  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1               CNN  ExtendedBallroom
# 5229_CNN_STFT_EXTENDEDBALLROOM_2               CNN  ExtendedBallroom
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1     CNN  ExtendedBallroom
# 5671_CNN_STFT_EXTENDEDBALLROOM_4               CNN  ExtendedBallroom
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2     CNN  ExtendedBallroom
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4     CNN  ExtendedBallroom
# 3375_CNN_STFT_EXTENDEDBALLROOM_5               CNN  ExtendedBallroom
# 7137_CNN_STFT_EXTENDEDBALLROOM_8               CNN  ExtendedBallroom
# 6968_CNN_STFT_EXTENDEDBALLROOM_10              CNN  ExtendedBallroom
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5     CNN  ExtendedBallroom
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8     CNN  ExtendedBallroom
# 8137_CNN_STFT_GTZAN_4                          CNN             GTZAN
# 1244_CNN_STFT_GTZAN_8                          CNN             GTZAN
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2               CNN  ExtendedBallroom
# 9446_CNN_STFT_GTZAN_5                          CNN             GTZAN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10    CNN  ExtendedBallroom
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5               CNN  ExtendedBallroom
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                CNN             GTZAN
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                CNN             GTZAN
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                CNN  ExtendedBallroom
# 9658_CNN_MELSPECTROGRAM_GTZAN_10               CNN             GTZAN
# 594_CNN_STFT_GTZAN_10                          CNN             GTZAN
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8               CNN  ExtendedBallroom
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                CNN             GTZAN
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10              CNN  ExtendedBallroom
# 5027_CNN_MFCC_GTZAN_10                         CNN             GTZAN
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                CNN             GTZAN
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                CNN             GTZAN
# 4131_CNN_MFCC_GTZAN_8                          CNN             GTZAN
# 8125_CNN_MFCC_GTZAN_4                          CNN             GTZAN
# 4089_CNN_MFCC_GTZAN_2                          CNN             GTZAN
# 2574_CNN_MFCC_GTZAN_5                          CNN             GTZAN
# 8918_CNN_MFCC_GTZAN_1                          CNN             GTZAN
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1               CNN  ExtendedBallroom
# 2305_CNN_STFT_GTZAN_2                          CNN             GTZAN
# 3009_CNN_STFT_GTZAN_1                          CNN             GTZAN
#
#                                                     Feature  Split  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                       STFT      1
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                       STFT      2
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1   MELSPECTROGRAM      1
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                       STFT      4
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2   MELSPECTROGRAM      2
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4   MELSPECTROGRAM      4
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                       STFT      5
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                       STFT      8
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                      STFT     10
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5   MELSPECTROGRAM      5
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8   MELSPECTROGRAM      8
# 8137_CNN_STFT_GTZAN_4                                  STFT      4
# 1244_CNN_STFT_GTZAN_8                                  STFT      8
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                       MFCC      2
# 9446_CNN_STFT_GTZAN_5                                  STFT      5
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10  MELSPECTROGRAM     10
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                       MFCC      5
# 7613_CNN_MELSPECTROGRAM_GTZAN_8              MELSPECTROGRAM      8
# 4092_CNN_MELSPECTROGRAM_GTZAN_4              MELSPECTROGRAM      4
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                        MFCC      4
# 9658_CNN_MELSPECTROGRAM_GTZAN_10             MELSPECTROGRAM     10
# 594_CNN_STFT_GTZAN_10                                  STFT     10
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                       MFCC      8
# 1828_CNN_MELSPECTROGRAM_GTZAN_5              MELSPECTROGRAM      5
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                      MFCC     10
# 5027_CNN_MFCC_GTZAN_10                                 MFCC     10
# 6844_CNN_MELSPECTROGRAM_GTZAN_2              MELSPECTROGRAM      2
# 7242_CNN_MELSPECTROGRAM_GTZAN_1              MELSPECTROGRAM      1
# 4131_CNN_MFCC_GTZAN_8                                  MFCC      8
# 8125_CNN_MFCC_GTZAN_4                                  MFCC      4
# 4089_CNN_MFCC_GTZAN_2                                  MFCC      2
# 2574_CNN_MFCC_GTZAN_5                                  MFCC      5
# 8918_CNN_MFCC_GTZAN_1                                  MFCC      1
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                       MFCC      1
# 2305_CNN_STFT_GTZAN_2                                  STFT      2
# 3009_CNN_STFT_GTZAN_1                                  STFT      1
#
#                                              Test Accuracy  Test Loss  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                  0.926158   0.492275
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                  0.921728   0.482177
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1        0.914894   0.658619
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                  0.913901   0.452483
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2        0.911083   0.594169
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4        0.904822   0.517555
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                  0.903808   0.492371
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                  0.903413   0.473348
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                 0.894664   0.462838
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5        0.894289   0.490980
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8        0.870539   0.532035
# 8137_CNN_STFT_GTZAN_4                             0.863750   0.676039
# 1244_CNN_STFT_GTZAN_8                             0.863125   0.633470
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                  0.856606   0.609721
# 9446_CNN_STFT_GTZAN_5                             0.855000   0.704794
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10       0.850576   0.565288
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                  0.845190   0.608070
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                   0.840000   0.666696
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                   0.837500   0.829763
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                   0.834377   0.645957
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                  0.833000   0.694613
# 594_CNN_STFT_GTZAN_10                             0.825000   0.776264
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                  0.815435   0.649893
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                   0.815000   0.824581
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                 0.805361   0.682126
# 5027_CNN_MFCC_GTZAN_10                            0.759000   0.877874
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                   0.737500   1.305225
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                   0.715000   1.612592
# 4131_CNN_MFCC_GTZAN_8                             0.701250   1.002084
# 8125_CNN_MFCC_GTZAN_4                             0.670000   1.136008
# 4089_CNN_MFCC_GTZAN_2                             0.615000   1.395971
# 2574_CNN_MFCC_GTZAN_5                             0.610000   1.189536
# 8918_CNN_MFCC_GTZAN_1                             0.600000   1.464577
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                  0.418023   1.661914
# 2305_CNN_STFT_GTZAN_2                             0.232500   3.644374
# 3009_CNN_STFT_GTZAN_1                             0.155000   3.032088
#
#                                              Train Accuracy  Train Loss  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                   0.958660    0.383785
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                   0.951307    0.384229
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1         0.976198    0.472831
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                   0.967042    0.299174
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2         0.944105    0.448364
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4         0.929936    0.414237
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                   0.945140    0.365856
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                   0.947432    0.318092
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                  0.934463    0.352995
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5         0.930173    0.379099
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8         0.895804    0.451633
# 8137_CNN_STFT_GTZAN_4                              0.945000    0.483719
# 1244_CNN_STFT_GTZAN_8                              0.935000    0.463009
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                   0.922499    0.395239
# 9446_CNN_STFT_GTZAN_5                              0.949250    0.452553
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10        0.883079    0.485902
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                   0.910571    0.413887
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                    0.904375    0.532134
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                    0.936250    0.545210
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                    0.879834    0.499070
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                   0.903500    0.525064
# 594_CNN_STFT_GTZAN_10                              0.878875    0.640911
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                   0.874706    0.499801
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                    0.930750    0.550798
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                  0.852987    0.566167
# 5027_CNN_MFCC_GTZAN_10                             0.910000    0.491272
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                    0.927500    0.860409
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                    0.910000    1.002662
# 4131_CNN_MFCC_GTZAN_8                              0.798437    0.791681
# 8125_CNN_MFCC_GTZAN_4                              0.735313    0.961560
# 4089_CNN_MFCC_GTZAN_2                              0.834375    0.733817
# 2574_CNN_MFCC_GTZAN_5                              0.704500    1.001700
# 8918_CNN_MFCC_GTZAN_1                              0.752500    1.063264
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                   0.452866    1.547002
# 2305_CNN_STFT_GTZAN_2                              0.250000    3.590334
# 3009_CNN_STFT_GTZAN_1                              0.150000    3.054073
#
#                                              Best Epoch  Validation Accuracy  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                   65.0             0.924883
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                   38.0             0.917058
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1         99.0             0.917058
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                   48.0             0.921722
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2         51.0             0.918623
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4         51.0             0.901761
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                   39.0             0.910770
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                   53.0             0.895499
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                  48.0             0.891046
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5         75.0             0.900751
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8         68.0             0.863992
# 8137_CNN_STFT_GTZAN_4                              97.0             0.867188
# 1244_CNN_STFT_GTZAN_8                              93.0             0.842188
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                   50.0             0.874022
# 9446_CNN_STFT_GTZAN_5                              98.0             0.883750
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10        75.0             0.860520
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                   57.0             0.852223
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                    93.0             0.837500
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                    96.0             0.832812
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                    38.0             0.823875
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                   98.0             0.831250
# 594_CNN_STFT_GTZAN_10                              49.0             0.820000
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                   64.0             0.812720
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                    87.0             0.851250
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                  54.0             0.810426
# 5027_CNN_MFCC_GTZAN_10                             74.0             0.753750
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                    83.0             0.746875
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                   100.0             0.675000
# 4131_CNN_MFCC_GTZAN_8                              37.0             0.715625
# 8125_CNN_MFCC_GTZAN_4                              32.0             0.651563
# 4089_CNN_MFCC_GTZAN_2                              74.0             0.618750
# 2574_CNN_MFCC_GTZAN_5                              25.0             0.657500
# 8918_CNN_MFCC_GTZAN_1                              50.0             0.537500
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                   19.0             0.430360
# 2305_CNN_STFT_GTZAN_2                               8.0             0.265625
# 3009_CNN_STFT_GTZAN_1                              31.0             0.131250
#
#                                              Validation Loss  \
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                    0.519129
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                    0.478434
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1          0.693581
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                    0.423758
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2          0.539827
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4          0.486075
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                    0.472410
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                    0.492155
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                   0.484993
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5          0.461575
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8          0.547042
# 8137_CNN_STFT_GTZAN_4                               0.677746
# 1244_CNN_STFT_GTZAN_8                               0.689365
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                    0.538685
# 9446_CNN_STFT_GTZAN_5                               0.622703
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10         0.551345
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                    0.582936
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                     0.699608
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                     0.793306
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                     0.646351
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                    0.681375
# 594_CNN_STFT_GTZAN_10                               0.773292
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                    0.667756
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                     0.730788
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                   0.680366
# 5027_CNN_MFCC_GTZAN_10                              0.885925
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                     1.335944
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                     1.634010
# 4131_CNN_MFCC_GTZAN_8                               1.008555
# 8125_CNN_MFCC_GTZAN_4                               1.181566
# 4089_CNN_MFCC_GTZAN_2                               1.305525
# 2574_CNN_MFCC_GTZAN_5                               1.105547
# 8918_CNN_MFCC_GTZAN_1                               1.590665
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                    1.616881
# 2305_CNN_STFT_GTZAN_2                               3.621947
# 3009_CNN_STFT_GTZAN_1                               3.020921
#
#                                              Training Accuracy  Training Loss
# Model Name
# 7655_CNN_STFT_EXTENDEDBALLROOM_1                      0.940094       0.407142
# 5229_CNN_STFT_EXTENDEDBALLROOM_2                      0.929340       0.423746
# 5273_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_1            0.942443       0.552301
# 5671_CNN_STFT_EXTENDEDBALLROOM_4                      0.941384       0.360010
# 6520_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_2            0.892543       0.593064
# 7753_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_4            0.860750       0.602696
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                      0.926570       0.398633
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                      0.923329       0.383254
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                     0.903867       0.443369
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5            0.866291       0.575260
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8            0.814170       0.681277
# 8137_CNN_STFT_GTZAN_4                                 0.900000       0.594516
# 1244_CNN_STFT_GTZAN_8                                 0.893555       0.548206
# 4517_CNN_MFCC_EXTENDEDBALLROOM_2                      0.858094       0.573251
# 9446_CNN_STFT_GTZAN_5                                 0.924062       0.511928
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10           0.802998       0.721659
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                      0.842101       0.600618
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                       0.788477       0.788671
# 4092_CNN_MELSPECTROGRAM_GTZAN_4                       0.846094       0.748227
# 168_CNN_MFCC_EXTENDEDBALLROOM_4                       0.814268       0.686080
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                      0.806094       0.753516
# 594_CNN_STFT_GTZAN_10                                 0.817187       0.771090
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                      0.797240       0.704463
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                       0.833125       0.761293
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                     0.763582       0.805233
# 5027_CNN_MFCC_GTZAN_10                                0.817813       0.689063
# 6844_CNN_MELSPECTROGRAM_GTZAN_2                       0.844531       0.961141
# 7242_CNN_MELSPECTROGRAM_GTZAN_1                       0.875000       1.035009
# 4131_CNN_MFCC_GTZAN_8                                 0.712305       0.978918
# 8125_CNN_MFCC_GTZAN_4                                 0.702344       1.024330
# 4089_CNN_MFCC_GTZAN_2                                 0.871094       0.639399
# 2574_CNN_MFCC_GTZAN_5                                 0.655000       1.130932
# 8918_CNN_MFCC_GTZAN_1                                 0.720312       1.106304
# 2867_CNN_MFCC_EXTENDEDBALLROOM_1                      0.492561       1.449357
# 2305_CNN_STFT_GTZAN_2                                 0.392969       3.350461
# 3009_CNN_STFT_GTZAN_1                                 0.435937       2.323962

# %%
for d in ['GTZAN', 'ExtendedBallroom']:
    print(d + ':')
    for i in [1, 2, 4, 5, 8, 10]:
        temp = MODELS[MODELS["Split"] == i]
        temp = temp[temp['Dataset'] == d]
        test_a = temp["Test Accuracy"].mean()
        train_a = temp["Train Accuracy"].mean()
        v = temp["Validation Loss"].mean()
        print(f"{i} split: Avg test Accuracy: {test_a:.3f}, Avg train Accuracy: {train_a:.3f}, Avg validation Loss: {v:.3f}")
        
print("Total")
for i in [1, 2, 4, 5, 8, 10]:
    temp = MODELS[MODELS["Split"] == i]
    test_a = temp["Test Accuracy"].mean()
    train_a = temp["Train Accuracy"].mean()
    v = temp["Validation Loss"].mean()
    print(f"{i} split: Avg test Accuracy: {test_a:.3f}, Avg train Accuracy: {train_a:.3f}, Avg validation Loss: {v:.3f}")
# Out:
# GTZAN:
# 1 split: Avg test Accuracy: 0.490, Avg train Accuracy: 0.604, Avg validation Loss: 2.082
# 2 split: Avg test Accuracy: 0.528, Avg train Accuracy: 0.671, Avg validation Loss: 2.088
# 4 split: Avg test Accuracy: 0.790, Avg train Accuracy: 0.872, Avg validation Loss: 0.884
# 5 split: Avg test Accuracy: 0.760, Avg train Accuracy: 0.862, Avg validation Loss: 0.820
# 8 split: Avg test Accuracy: 0.801, Avg train Accuracy: 0.879, Avg validation Loss: 0.799
# 10 split: Avg test Accuracy: 0.806, Avg train Accuracy: 0.897, Avg validation Loss: 0.780
# ExtendedBallroom:
# 1 split: Avg test Accuracy: 0.753, Avg train Accuracy: 0.796, Avg validation Loss: 0.943
# 2 split: Avg test Accuracy: 0.896, Avg train Accuracy: 0.939, Avg validation Loss: 0.519
# 4 split: Avg test Accuracy: 0.884, Avg train Accuracy: 0.926, Avg validation Loss: 0.519
# 5 split: Avg test Accuracy: 0.881, Avg train Accuracy: 0.929, Avg validation Loss: 0.506
# 8 split: Avg test Accuracy: 0.863, Avg train Accuracy: 0.906, Avg validation Loss: 0.569
# 10 split: Avg test Accuracy: 0.850, Avg train Accuracy: 0.890, Avg validation Loss: 0.572
# Total
# 1 split: Avg test Accuracy: 0.622, Avg train Accuracy: 0.700, Avg validation Loss: 1.513
# 2 split: Avg test Accuracy: 0.712, Avg train Accuracy: 0.805, Avg validation Loss: 1.303
# 4 split: Avg test Accuracy: 0.837, Avg train Accuracy: 0.899, Avg validation Loss: 0.701
# 5 split: Avg test Accuracy: 0.821, Avg train Accuracy: 0.895, Avg validation Loss: 0.663
# 8 split: Avg test Accuracy: 0.832, Avg train Accuracy: 0.893, Avg validation Loss: 0.684
# 10 split: Avg test Accuracy: 0.828, Avg train Accuracy: 0.894, Avg validation Loss: 0.676

# %% [markdown]
# ##### With the results above, I decided to use Split of 8s due to having more sample sizes which would lead to less overfitting and still having a high enough test accuracy.
#
# ## Confusion Matrix

# %%
dat = 'GTZAN'
feat = 'STFT'
split = 8
model = get_model('CNN', dat, feat, split)
X_train, X_test, Y_train, Y_test = getFeatures(dat, feat, split)
del X_train, Y_train # not needed

preds = model.predict(X_test)
cm = confusion_matrix(y_true = Y_test.argmax(axis = 1), y_pred = preds.argmax(axis = 1))
cnf_matrix(cm, GTZAN['genres'], name = f'{dat}-{feat}-{split}')

# %%
dat = 'ExtendedBallroom'
model = get_model('CNN', dat, feat, split)
dat = 'Extended Ballroom'
X_train, X_test, Y_train, Y_test = getFeatures(dat, feat, split)
del X_train, Y_train # not needed

preds = model.predict(X_test)
cm = confusion_matrix(y_true = Y_test.argmax(axis = 1), y_pred = preds.argmax(axis = 1))
cnf_matrix(cm, EXTENDED_BALLROOM['genres'], name = f'{dat}-{feat}-{split}')

# %% [markdown]
# # Dual CNN + Classical
#
# ![Dual CNN + Classical](images/DUALCNNCLASSICAL.png)

# %%
def classical_parallel_model(model1, x_train1, x_test1, y_train1, y_test1, 
                             model2, x_train2, x_test2, y_train2, y_test2,
                             num_genres, name, classifier):
    # layer name need to be unique
    i = 0
    for layer in model1.layers:
        layer._name += f"_{i}"
        i += 1
    for layer in model2.layers:
        layer._name += f"_{i}"
        i += 1
    
    m1_layer = [l.output for l in model1.layers if type(l) == Flatten][0]
    m2_layer = [l.output for l in model2.layers if type(l) == Flatten][0]
    m1 = Model(inputs = model1.input, outputs = m1_layer)
    m2 = Model(inputs = model2.input, outputs = m2_layer)

    # feature extraction
    m1_output = m1.predict(x_train1)
    m2_output = m2.predict(x_train2)
    output_features = np.column_stack((m1_output, m2_output)) # concatenation
    
    global X_train1, X_train2
    del X_train1, X_train2, x_train1, x_train2 # delete unneeded  var cuz takes up too much space

    # testing
    testing_m1_output = m1.predict(x_test1)
    testing_m2_output = m2.predict(x_test2)
    testing_output_features = np.column_stack((testing_m1_output, testing_m2_output)) # concatenation
    
    global X_test1, X_test2
    del X_test1, X_test2, x_test1, x_test2 # delete unneeded var cuz takes up too much space

    notOHE = [np.argmax(x) for x in y_train2] # inverse one hot encoding - ytrain2 and ytrain1 same
    notOHEtest = [np.argmax(x) for x in y_test1] # ytest1, ytest2 same
    
    global Y_train1, Y_train2, Y_test1, Y_test2
    del Y_train1, Y_train2, Y_test1, Y_test2, y_train1, y_train2, y_test1, y_test2
    
    PIPING = [
        ('scaling', StandardScaler()), 
        # Standardize features by removing the mean and scaling to unit variance
        ('variance_tresh', VarianceThreshold(threshold=(0.1))), 
        # removes low variance features
        ('feature_selection', SelectFromModel(lgbm.LGBMClassifier()))
        # Meta-transformer for selecting features based on importance weights.
        # Light gradient boosting model -- fastest while being accurate
    ]

    if classifier == 'rf':
        params = {
            "algo__n_estimators": [100, 200, 300, 500],
            "algo__criterion": ["gini", "entropy"],
            "algo__max_depth": [10, None]
        }
        PIPING.append(('algo', RandomForestClassifier()))
        pipe = Pipeline(PIPING)
    elif classifier == 'lr':
        params = {
            "algo__penalty": ["l2"],
            "algo__C": [0.1, 0.25, 0.5],
            "algo__max_iter": [500],
            "algo__solver": ["lbfgs"]
        }
        PIPING.append(('algo', LogisticRegression()))
        pipe = Pipeline(PIPING)
    elif classifier == 'svm':
        params = {
            "algo__C": [0.25, 0.5, 2, 4, 6],
            "algo__kernel": ['rbf', 'linear'],
        }
        PIPING.append(('algo', SVC()))
        pipe = Pipeline(PIPING)
    elif classifier == 'knn':
        params = {
            'algo__n_neighbors': [3, 5, 7, 10],
            'algo__metric': ['euclidean']
        }
        PIPING.append(('nca', NeighborhoodComponentsAnalysis()))
        PIPING.append(('algo', KNeighborsClassifier()))
        pipe = Pipeline(PIPING)
    
    grid = GridSearchCV(pipe, params, scoring = 'accuracy', n_jobs = 6, cv = 10, verbose = 3)
    grid.fit(output_features, notOHE)
    val_acc = grid.best_score_
    print("best score on validation set (accuracy) = {:.4f}".format(grid.best_score_))
    
    preds = grid.predict(output_features)
    train_acc = accuracy_score(preds, notOHE)
    print("best score on training set (accuracy) = {:.4f}".format(accuracy_score(preds, notOHE)))

    preds = grid.predict(testing_output_features)
    test_acc = accuracy_score(preds, notOHEtest)
    print("best score on test set (accuracy) = {:.4f}".format(accuracy_score(preds, notOHEtest)))
    
    return (grid, test_acc, train_acc, val_acc)

# %%
def parallel_model(model1, model2, num_genres, name):
    # layer name need to be unique
    i = 0
    for layer in model1.layers:
        layer._name += f"_{i}"
        i += 1
    for layer in model2.layers:
        layer._name += f"_{i}"
        i += 1
    
    # get flattened layer for each
    m1_layer = [l.output for l in model1.layers if type(l) == Flatten][0]
    m2_layer = [l.output for l in model2.layers if type(l) == Flatten][0]
    
    # Merged models
    merged = Concatenate()([m1_layer, m2_layer])
    
    x = Flatten()(merged)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', 
              kernel_regularizer = tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.25)(x)
    
    predictions = Dense(num_genres, 
                        activation='softmax', 
                        kernel_regularizer = tf.keras.regularizers.l2(0.02))(x)
    
    model = Model(inputs = [model1.input, model2.input], outputs=predictions, name = name)
    return model

# %% [markdown]
# ## STFT + MFCC
#
# ![STFT](images/STFT.png)
# ![MFCC](images/MFCC.png)

# %% [markdown]
# ### GTZAN

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'GTZAN' # for name
DATA = "GTZAN" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MFCC'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, GTZAN['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 30
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'GTZAN' # for name
    DATA = "GTZAN" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'STFT'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MFCC'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
    
    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                GTZAN['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ### Extended Ballroom

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'ExtendedBallroom' # for name, cant have space
DATA = "EXTENDED BALLROOM" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MFCC'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 19
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'ExtendedBallroom' # for name, cant have space
    DATA = "EXTENDED BALLROOM" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'STFT'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MFCC'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)

    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                EXTENDED_BALLROOM['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ## STFT + MELSPECTROGRAM
#
# ![STFT](images/STFT.png)
# ![MELSPECTROGRAM](images/MELSPECTROGRAM.png)

# %% [markdown]
# ### GTZAN

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'GTZAN' # for name
DATA = "GTZAN" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MELSPECTROGRAM'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
# Ytest_1, Y_test2 are equal, same with train

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, GTZAN['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 18
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'GTZAN' # for name
    DATA = "GTZAN" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'STFT'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MELSPECTROGRAM'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
    
    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                GTZAN['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ### Extended Ballroom

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'ExtendedBallroom' # for name, cant have space
DATA = "EXTENDED BALLROOM" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MELSPECTROGRAM'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
# Ytest_1, Y_test2 are equal, same with train

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 15
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
classifiers = ['knn'] # takes too long -- takes up too much memory
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'ExtendedBallroom' # for name, cant have space
    DATA = "EXTENDED BALLROOM" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'STFT'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MELSPECTROGRAM'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)

    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                EXTENDED_BALLROOM['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ## MFCC + MELSPECTROGRAM
#
# ![MFCC](images/MFCC.png)
# ![MELSPECTROGRAM](images/MELSPECTROGRAM.png)

# %% [markdown]
# ### GTZAN

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'GTZAN' # for name
DATA = "GTZAN" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'MFCC'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MELSPECTROGRAM'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
# Ytest_1, Y_test2 are equal, same with train

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, GTZAN['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 40
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'GTZAN' # for name
    DATA = "GTZAN" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'MFCC'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MELSPECTROGRAM'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
    
    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                GTZAN['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# ### Extended Ballroom

# %%
# Get Features and Models
split = 8
mod = 'CNN'
dat = 'ExtendedBallroom' # for name, cant have space
DATA = "EXTENDED BALLROOM" # to get feature
uid = np.random.randint(1, 10000) # 'unique' id
while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
    uid = np.random.randint(1, 10000)
    
feat1 = 'MFCC'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

feat2 = 'MELSPECTROGRAM'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
# Ytest_1, Y_test2 are equal, same with train

name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, dat, str(split)]])

# %% [markdown]
# #### Base

# %%
m = parallel_model(model1, model2, EXTENDED_BALLROOM['nGenres'], name)
opt = keras.optimizers.Adam(lr = 0.001)
m.compile(optimizer = opt, loss = "categorical_crossentropy", metrics = ['categorical_accuracy'])
m.summary()

# %%
checkpoint_path = 'checkpoints/{val_loss:.2f}-{epoch:02d}.hdf5'
history = m.fit([X_train1, X_train2], Y_train1, epochs = 100, batch_size = BATCH_SIZE, validation_split = 0.2,
     callbacks = [EarlyStopping(monitor = 'val_loss', mode = 'auto', patience = 15),
                 ModelCheckpoint(filepath = checkpoint_path, save_weights_only = False,
                                monitor = 'val_loss', mode = 'min',
                                save_best_only = True)])

# %%
plot_graph(history, name)

# %%
best_epoch = 12
train_acc, train_loss, val_acc, val_loss = get_res(history, best_epoch)
#print(train_acc, val_acc, train_loss, val_loss)

m.load_weights(f'checkpoints/{val_loss:.2f}-{best_epoch:02d}.hdf5') # gets the best model weights

# %%
train = m.evaluate([X_train1, X_train2], Y_train1)
print("Train Loss:", train[0])
print("Train Accuracy:", train[1])
test = m.evaluate([X_test1, X_test2], Y_test1)
print("Test Loss:", test[0])
print("Test Accuracy:", test[1])

# %%
m.save(f'models/{name}.h5') # save model
# save stats of model
cur_mod_stats = pd.DataFrame([[name, mod, dat, ', '.join([feat1, feat2]), split, test[1], test[0], train[1], train[0],
                             best_epoch, val_acc, val_loss, train_acc, train_loss]], columns = MODEL_COLS)
cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# #### Classical

# %%
classifiers = ['lr', 'rf', 'svm', 'knn']
for classifier in classifiers:
    # Get Features and Models
    split = 8
    mod = 'CNN'
    dat = 'ExtendedBallroom' # for name, cant have space
    DATA = "EXTENDED BALLROOM" # to get feature
    uid = np.random.randint(1, 10000) # 'unique' id
    while sum([x.startswith(str(uid)) for x in os.listdir('models/')]) != 0: # if duplicate
        uid = np.random.randint(1, 10000)

    feat1 = 'MFCC'
    model1 = get_model(mod, dat, feat1, split)
    X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)

    feat2 = 'MELSPECTROGRAM'
    model2 = get_model(mod, dat, feat2, split)
    X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)

    name = '_'.join([x.upper() for x in [str(uid), mod, feat1, feat2, classifier, dat, str(split)]])
    
    # training
    pm, test_acc, train_acc, val_acc = classical_parallel_model(model1, X_train1, X_test1, Y_train1, Y_test1,
                                                                model2, X_train2, X_test2, Y_train2, Y_test2,
                                                                EXTENDED_BALLROOM['nGenres'], name, classifier)
    
    joblib.dump(pm, f'models/{name}.pkl') # save model
    # save stats of model
    cur_mod_stats = pd.DataFrame([[name, mod + " + " + classifier.upper(), dat, ', '.join([feat1, feat2]), split, 
                                   test_acc, None, train_acc, None,
                                 None, val_acc, None, None, None]], columns = MODEL_COLS)
    cur_mod_stats.to_csv('models/models.csv', mode = 'a', header = False, index = False)

# %% [markdown]
# # Final Results

# %%
name = '5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8'
model = joblib.load(f'models/{name}.pkl')
model_df = pd.DataFrame(model.cv_results_)
model_df.sort_values(by = ['rank_test_score'])
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     660.721866    429.673880         0.000000        0.000000
# 1     944.128096   2646.022085         2.027270        6.081811
# 2    1223.710365   2817.421700         2.306234        6.918703
# 3     308.498199     87.100520         0.000000        0.000000
#
#   param_algo__metric param_algo__n_neighbors  \
# 0          euclidean                       3
# 1          euclidean                       5
# 2          euclidean                       7
# 3          euclidean                      10
#
#                                               params  split0_test_score  \
# 0  {'algo__metric': 'euclidean', 'algo__n_neighbo...                NaN
# 1  {'algo__metric': 'euclidean', 'algo__n_neighbo...                NaN
# 2  {'algo__metric': 'euclidean', 'algo__n_neighbo...                NaN
# 3  {'algo__metric': 'euclidean', 'algo__n_neighbo...                NaN
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN           0.966341                NaN                NaN
# 3                NaN                NaN                NaN                NaN
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0                NaN              NaN             NaN                1
# 1           0.911903              NaN             NaN                2
# 2                NaN              NaN             NaN                3
# 3                NaN              NaN             NaN                4

# %% [markdown]
# Keep in mind, for some models, KNN has NaN values for split test scores and validation accuracy for reasons I am not sure of. Probably due to memory issues? Ex. 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8, 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLROOM_8, 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLROOM_8
#
# So the KNN models, at least for the models specified above, do not have the best possible accuracy.

# %%
MODELS_PATH = os.path.join(os.getcwd(), 'models', 'models.csv')
MODELS = pd.read_csv(MODELS_PATH).set_index("Model Name")
MODELS = MODELS.sort_values('Test Accuracy', ascending = False)
MODELS = MODELS[MODELS['Split'].isin([5, 8, 10])]
MODELS
# Out:
#                                                        Method  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8            CNN + KNN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                      CNN + KNN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8             CNN + SVM
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                      CNN + SVM
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8              CNN + LR
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8            CNN + SVM
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                        CNN + LR
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8             CNN + RF
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...  CNN + SVM
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8           CNN + KNN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                        CNN + RF
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8              CNN + RF
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8    CNN + RF
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8             CNN + LR
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  CNN + KNN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                     CNN
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8   CNN + LR
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8           CNN
# 3857_CNN_STFT_MFCC_GTZAN_8                                CNN
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                      CNN
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                          CNN
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                          CNN
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8  CNN + SVM
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8            CNN + KNN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                         CNN
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5                CNN
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                      CNN
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8            CNN + SVM
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8           CNN
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8   CNN + LR
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8   CNN + RF
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  CNN + KNN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8                CNN
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8              CNN + LR
# 1244_CNN_STFT_GTZAN_8                                     CNN
# 9446_CNN_STFT_GTZAN_5                                     CNN
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8              CNN + RF
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10               CNN
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                          CNN
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                           CNN
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                          CNN
# 594_CNN_STFT_GTZAN_10                                     CNN
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                          CNN
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                           CNN
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                         CNN
# 5027_CNN_MFCC_GTZAN_10                                    CNN
# 4131_CNN_MFCC_GTZAN_8                                     CNN
# 2574_CNN_MFCC_GTZAN_5                                     CNN
#
#                                                              Dataset  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                       GTZAN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                 GTZAN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                        GTZAN
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                 GTZAN
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                        GTZAN
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8            ExtendedBallroom
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                  GTZAN
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8            ExtendedBallroom
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...  ExtendedBallroom
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8           ExtendedBallroom
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                  GTZAN
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                        GTZAN
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8   ExtendedBallroom
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8            ExtendedBallroom
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  ExtendedBallroom
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8               ExtendedBallroom
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8  ExtendedBallroom
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8     ExtendedBallroom
# 3857_CNN_STFT_MFCC_GTZAN_8                                     GTZAN
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                           GTZAN
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                    ExtendedBallroom
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                    ExtendedBallroom
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8  ExtendedBallroom
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                       GTZAN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                   ExtendedBallroom
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5          ExtendedBallroom
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                           GTZAN
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                       GTZAN
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8     ExtendedBallroom
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8  ExtendedBallroom
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8  ExtendedBallroom
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  ExtendedBallroom
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8          ExtendedBallroom
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                        GTZAN
# 1244_CNN_STFT_GTZAN_8                                          GTZAN
# 9446_CNN_STFT_GTZAN_5                                          GTZAN
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                        GTZAN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10         ExtendedBallroom
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                    ExtendedBallroom
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                                GTZAN
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                               GTZAN
# 594_CNN_STFT_GTZAN_10                                          GTZAN
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                    ExtendedBallroom
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                                GTZAN
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                   ExtendedBallroom
# 5027_CNN_MFCC_GTZAN_10                                         GTZAN
# 4131_CNN_MFCC_GTZAN_8                                          GTZAN
# 2574_CNN_MFCC_GTZAN_5                                          GTZAN
#
#                                                                  Feature  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8            STFT, MELSPECTROGRAM
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                STFT, MFCC
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8             STFT, MELSPECTROGRAM
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                STFT, MFCC
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8             STFT, MELSPECTROGRAM
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                      STFT, MFCC
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                 STFT, MFCC
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                      STFT, MFCC
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...  STFT, MELSPECTROGRAM
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                     STFT, MFCC
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                 STFT, MFCC
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8             STFT, MELSPECTROGRAM
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8   STFT, MELSPECTROGRAM
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                      STFT, MFCC
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  STFT, MELSPECTROGRAM
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                         STFT, MFCC
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8  STFT, MELSPECTROGRAM
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8     STFT, MELSPECTROGRAM
# 3857_CNN_STFT_MFCC_GTZAN_8                                    STFT, MFCC
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                STFT, MELSPECTROGRAM
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                                    STFT
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                                    STFT
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8  MFCC, MELSPECTROGRAM
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8            MFCC, MELSPECTROGRAM
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                                   STFT
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5                MELSPECTROGRAM
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                MFCC, MELSPECTROGRAM
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8            MFCC, MELSPECTROGRAM
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8     MFCC, MELSPECTROGRAM
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8  MFCC, MELSPECTROGRAM
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8  MFCC, MELSPECTROGRAM
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...  MFCC, MELSPECTROGRAM
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8                MELSPECTROGRAM
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8             MFCC, MELSPECTROGRAM
# 1244_CNN_STFT_GTZAN_8                                               STFT
# 9446_CNN_STFT_GTZAN_5                                               STFT
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8             MFCC, MELSPECTROGRAM
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10               MELSPECTROGRAM
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                                    MFCC
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                           MELSPECTROGRAM
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                          MELSPECTROGRAM
# 594_CNN_STFT_GTZAN_10                                               STFT
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                                    MFCC
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                           MELSPECTROGRAM
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                                   MFCC
# 5027_CNN_MFCC_GTZAN_10                                              MFCC
# 4131_CNN_MFCC_GTZAN_8                                               MFCC
# 2574_CNN_MFCC_GTZAN_5                                               MFCC
#
#                                                     Split  Test Accuracy  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                8       0.958125
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                          8       0.953125
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                 8       0.950625
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                          8       0.940000
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                 8       0.932500
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                8       0.924076
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                           8       0.921250
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                8       0.919693
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...      8       0.919537
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8               8       0.918284
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                           8       0.916875
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                 8       0.916250
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8       8       0.915780
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                8       0.914684
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...      8       0.914058
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                   8       0.913118
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8      8       0.912805
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8         8       0.911240
# 3857_CNN_STFT_MFCC_GTZAN_8                              8       0.908750
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                    8       0.905625
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                        5       0.903808
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                        8       0.903413
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8      8       0.898403
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                8       0.897500
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                      10       0.894664
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5              5       0.894289
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                    8       0.891875
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                8       0.891250
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8         8       0.891202
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8      8       0.889167
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8      8       0.883688
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...      8       0.877113
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8              8       0.870539
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                 8       0.869375
# 1244_CNN_STFT_GTZAN_8                                   8       0.863125
# 9446_CNN_STFT_GTZAN_5                                   5       0.855000
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                 8       0.853125
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10            10       0.850576
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                        5       0.845190
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                         8       0.840000
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                       10       0.833000
# 594_CNN_STFT_GTZAN_10                                  10       0.825000
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                        8       0.815435
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                         5       0.815000
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                      10       0.805361
# 5027_CNN_MFCC_GTZAN_10                                 10       0.759000
# 4131_CNN_MFCC_GTZAN_8                                   8       0.701250
# 2574_CNN_MFCC_GTZAN_5                                   5       0.610000
#
#                                                     Test Loss  Train Accuracy  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                  NaN        0.990000
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                            NaN        0.990938
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                   NaN        0.999375
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                            NaN        0.999375
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                   NaN        0.999375
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                  NaN        0.980194
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                             NaN        0.999062
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                  NaN        0.999843
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...        NaN        0.988414
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                 NaN        0.982543
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                             NaN        0.999375
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                   NaN        0.999375
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8         NaN        0.999843
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                  NaN        0.980312
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...        NaN        0.981290
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                0.453004        0.965203
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8        NaN        0.983208
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8      0.463117        0.963520
# 3857_CNN_STFT_MFCC_GTZAN_8                           0.541071        0.974219
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                 0.555994        0.970625
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                     0.492371        0.945140
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                     0.473348        0.947432
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8        NaN        0.964381
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                  NaN        0.970938
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                    0.462838        0.934463
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5           0.490980        0.930173
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                 0.556453        0.969531
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                  NaN        0.999375
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8      0.501286        0.928214
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8        NaN        0.953343
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8        NaN        0.999843
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...        NaN        0.965672
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8           0.532035        0.895804
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                   NaN        0.991094
# 1244_CNN_STFT_GTZAN_8                                0.633470        0.935000
# 9446_CNN_STFT_GTZAN_5                                0.704794        0.949250
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                   NaN        0.999375
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10          0.565288        0.883079
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                     0.608070        0.910571
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                      0.666696        0.904375
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                     0.694613        0.903500
# 594_CNN_STFT_GTZAN_10                                0.776264        0.878875
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                     0.649893        0.874706
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                      0.824581        0.930750
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                    0.682126        0.852987
# 5027_CNN_MFCC_GTZAN_10                               0.877874        0.910000
# 4131_CNN_MFCC_GTZAN_8                                1.002084        0.798437
# 2574_CNN_MFCC_GTZAN_5                                1.189536        0.704500
#
#                                                     Train Loss  Best Epoch  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                   NaN         NaN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                             NaN         NaN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                    NaN         NaN
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                             NaN         NaN
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                    NaN         NaN
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                   NaN         NaN
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                              NaN         NaN
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                   NaN         NaN
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...         NaN         NaN
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                  NaN         NaN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                              NaN         NaN
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                    NaN         NaN
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8          NaN         NaN
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                   NaN         NaN
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...         NaN         NaN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                 0.290492        19.0
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8         NaN         NaN
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8       0.301144        15.0
# 3857_CNN_STFT_MFCC_GTZAN_8                            0.341422        30.0
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                  0.370765        18.0
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                      0.365856        39.0
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                      0.318092        53.0
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8         NaN         NaN
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                   NaN         NaN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                     0.352995        48.0
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5            0.379099        75.0
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                  0.344940        40.0
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                   NaN         NaN
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8       0.395436        12.0
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8         NaN         NaN
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8         NaN         NaN
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...         NaN         NaN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8            0.451633        68.0
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                    NaN         NaN
# 1244_CNN_STFT_GTZAN_8                                 0.463009        93.0
# 9446_CNN_STFT_GTZAN_5                                 0.452553        98.0
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                    NaN         NaN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10           0.485902        75.0
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                      0.413887        57.0
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                       0.532134        93.0
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                      0.525064        98.0
# 594_CNN_STFT_GTZAN_10                                 0.640911        49.0
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                      0.499801        64.0
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                       0.550798        87.0
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                     0.566167        54.0
# 5027_CNN_MFCC_GTZAN_10                                0.491272        74.0
# 4131_CNN_MFCC_GTZAN_8                                 0.791681        37.0
# 2574_CNN_MFCC_GTZAN_5                                 1.001700        25.0
#
#                                                     Validation Accuracy  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                       0.975313
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                 0.972344
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                        0.981250
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                 0.977656
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                        0.971562
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                       0.960737
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                  0.968750
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                       0.954083
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...             0.960815
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                           NaN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                  0.951563
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                        0.953594
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8              0.953535
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                       0.957057
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...                  NaN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                          0.905088
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8             0.955844
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8                0.906262
# 3857_CNN_STFT_MFCC_GTZAN_8                                     0.893750
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                           0.898438
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                               0.910770
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                               0.895499
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8             0.931773
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                       0.929219
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                              0.891046
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5                     0.900751
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                           0.882812
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                       0.945781
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8                0.886888
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8             0.924218
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8             0.916429
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...                  NaN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8                     0.863992
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                        0.931250
# 1244_CNN_STFT_GTZAN_8                                          0.842188
# 9446_CNN_STFT_GTZAN_5                                          0.883750
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                        0.906563
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10                    0.860520
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                               0.852223
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                                0.837500
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                               0.831250
# 594_CNN_STFT_GTZAN_10                                          0.820000
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                               0.812720
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                                0.851250
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                              0.810426
# 5027_CNN_MFCC_GTZAN_10                                         0.753750
# 4131_CNN_MFCC_GTZAN_8                                          0.715625
# 2574_CNN_MFCC_GTZAN_5                                          0.657500
#
#                                                     Validation Loss  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                        NaN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                  NaN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                         NaN
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                  NaN
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                         NaN
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                        NaN
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                   NaN
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                        NaN
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...              NaN
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                       NaN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                   NaN
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                         NaN
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8               NaN
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                        NaN
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...              NaN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                      0.478700
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8              NaN
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8            0.480903
# 3857_CNN_STFT_MFCC_GTZAN_8                                 0.562724
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                       0.568121
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                           0.472410
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                           0.492155
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8              NaN
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                        NaN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                          0.484993
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5                 0.461575
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                       0.568622
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                        NaN
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8            0.520193
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8              NaN
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8              NaN
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...              NaN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8                 0.547042
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                         NaN
# 1244_CNN_STFT_GTZAN_8                                      0.689365
# 9446_CNN_STFT_GTZAN_5                                      0.622703
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                         NaN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10                0.551345
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                           0.582936
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                            0.699608
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                           0.681375
# 594_CNN_STFT_GTZAN_10                                      0.773292
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                           0.667756
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                            0.730788
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                          0.680366
# 5027_CNN_MFCC_GTZAN_10                                     0.885925
# 4131_CNN_MFCC_GTZAN_8                                      1.008555
# 2574_CNN_MFCC_GTZAN_5                                      1.105547
#
#                                                     Training Accuracy  \
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                          NaN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                    NaN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                           NaN
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                    NaN
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                           NaN
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                          NaN
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                     NaN
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                          NaN
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...                NaN
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                         NaN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                     NaN
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                           NaN
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8                 NaN
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                          NaN
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...                NaN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                        0.939035
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8                NaN
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8              0.933066
# 3857_CNN_STFT_MFCC_GTZAN_8                                   0.941602
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                         0.938086
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                             0.926570
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                             0.923329
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8                NaN
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                          NaN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                            0.903867
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5                   0.866291
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                         0.903711
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                          NaN
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8              0.867746
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8                NaN
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8                NaN
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...                NaN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8                   0.814170
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                           NaN
# 1244_CNN_STFT_GTZAN_8                                        0.893555
# 9446_CNN_STFT_GTZAN_5                                        0.924062
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                           NaN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10                  0.802998
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                             0.842101
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                              0.788477
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                             0.806094
# 594_CNN_STFT_GTZAN_10                                        0.817187
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                             0.797240
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                              0.833125
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                            0.763582
# 5027_CNN_MFCC_GTZAN_10                                       0.817813
# 4131_CNN_MFCC_GTZAN_8                                        0.712305
# 2574_CNN_MFCC_GTZAN_5                                        0.655000
#
#                                                     Training Loss
# Model Name
# 7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8                      NaN
# 6428_CNN_STFT_MFCC_KNN_GTZAN_8                                NaN
# 379_CNN_STFT_MELSPECTROGRAM_SVM_GTZAN_8                       NaN
# 4367_CNN_STFT_MFCC_SVM_GTZAN_8                                NaN
# 6475_CNN_STFT_MELSPECTROGRAM_LR_GTZAN_8                       NaN
# 757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8                      NaN
# 4630_CNN_STFT_MFCC_LR_GTZAN_8                                 NaN
# 1584_CNN_STFT_MFCC_RF_EXTENDEDBALLROOM_8                      NaN
# 5399_CNN_STFT_MELSPECTROGRAM_SVM_EXTENDEDBALLRO...            NaN
# 5201_CNN_STFT_MFCC_KNN_EXTENDEDBALLROOM_8                     NaN
# 5925_CNN_STFT_MFCC_RF_GTZAN_8                                 NaN
# 7802_CNN_STFT_MELSPECTROGRAM_RF_GTZAN_8                       NaN
# 693_CNN_STFT_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8             NaN
# 1941_CNN_STFT_MFCC_LR_EXTENDEDBALLROOM_8                      NaN
# 8311_CNN_STFT_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...            NaN
# 4734_CNN_STFT_MFCC_EXTENDEDBALLROOM_8                    0.352757
# 6199_CNN_STFT_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8            NaN
# 5948_CNN_STFT_MELSPECTROGRAM_EXTENDEDBALLROOM_8          0.382799
# 3857_CNN_STFT_MFCC_GTZAN_8                               0.405900
# 5031_CNN_STFT_MELSPECTROGRAM_GTZAN_8                     0.447174
# 3375_CNN_STFT_EXTENDEDBALLROOM_5                         0.398633
# 7137_CNN_STFT_EXTENDEDBALLROOM_8                         0.383254
# 823_CNN_MFCC_MELSPECTROGRAM_SVM_EXTENDEDBALLROOM_8            NaN
# 2317_CNN_MFCC_MELSPECTROGRAM_KNN_GTZAN_8                      NaN
# 6968_CNN_STFT_EXTENDEDBALLROOM_10                        0.443369
# 5461_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_5               0.575260
# 6448_CNN_MFCC_MELSPECTROGRAM_GTZAN_8                     0.500308
# 5327_CNN_MFCC_MELSPECTROGRAM_SVM_GTZAN_8                      NaN
# 2345_CNN_MFCC_MELSPECTROGRAM_EXTENDEDBALLROOM_8          0.562525
# 9590_CNN_MFCC_MELSPECTROGRAM_LR_EXTENDEDBALLROOM_8            NaN
# 3587_CNN_MFCC_MELSPECTROGRAM_RF_EXTENDEDBALLROOM_8            NaN
# 1288_CNN_MFCC_MELSPECTROGRAM_KNN_EXTENDEDBALLRO...            NaN
# 9483_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_8               0.681277
# 2093_CNN_MFCC_MELSPECTROGRAM_LR_GTZAN_8                       NaN
# 1244_CNN_STFT_GTZAN_8                                    0.548206
# 9446_CNN_STFT_GTZAN_5                                    0.511928
# 5676_CNN_MFCC_MELSPECTROGRAM_RF_GTZAN_8                       NaN
# 9243_CNN_MELSPECTROGRAM_EXTENDEDBALLROOM_10              0.721659
# 7675_CNN_MFCC_EXTENDEDBALLROOM_5                         0.600618
# 7613_CNN_MELSPECTROGRAM_GTZAN_8                          0.788671
# 9658_CNN_MELSPECTROGRAM_GTZAN_10                         0.753516
# 594_CNN_STFT_GTZAN_10                                    0.771090
# 6734_CNN_MFCC_EXTENDEDBALLROOM_8                         0.704463
# 1828_CNN_MELSPECTROGRAM_GTZAN_5                          0.761293
# 8789_CNN_MFCC_EXTENDEDBALLROOM_10                        0.805233
# 5027_CNN_MFCC_GTZAN_10                                   0.689063
# 4131_CNN_MFCC_GTZAN_8                                    0.978918
# 2574_CNN_MFCC_GTZAN_5                                    1.130932

# %%
# STFT MELSPECTOGRAM
split = 8
mod = 'CNN'
dat = 'GTZAN' # for name
DATA = "GTZAN" # to get feature
    
feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)
del X_train1, Y_train1

feat2 = 'MELSPECTROGRAM'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
del X_train2, Y_train2

m1_layer = [l.output for l in model1.layers if type(l) == Flatten][0]
m2_layer = [l.output for l in model2.layers if type(l) == Flatten][0]
m1 = Model(inputs = model1.input, outputs = m1_layer)
m2 = Model(inputs = model2.input, outputs = m2_layer)

# feature extraction
m1_output = m1.predict(X_test1)
m2_output = m2.predict(X_test2)
X_test = np.column_stack((m1_output, m2_output)) # concatenation

model_name = '7628_CNN_STFT_MELSPECTROGRAM_KNN_GTZAN_8'
model = joblib.load(f'models/{model_name}.pkl')

preds = model.predict(X_test)
cm = confusion_matrix(y_true = Y_test1.argmax(axis = 1), y_pred = preds)
cnf_matrix(cm, GTZAN['genres'], name = model_name)

# %%
# STFT MFCC
split = 8
mod = 'CNN'
dat = 'ExtendedBallroom' # for name, cant have space
DATA = "EXTENDED BALLROOM" # to get feature

feat1 = 'STFT'
model1 = get_model(mod, dat, feat1, split)
X_train1, X_test1, Y_train1, Y_test1 = getFeatures(DATA, feat1, split)
del X_train1, Y_train1

feat2 = 'MFCC'
model2 = get_model(mod, dat, feat2, split)
X_train2, X_test2, Y_train2, Y_test2 = getFeatures(DATA, feat2, split)
del X_train2, Y_train2

m1_layer = [l.output for l in model1.layers if type(l) == Flatten][0]
m2_layer = [l.output for l in model2.layers if type(l) == Flatten][0]
m1 = Model(inputs = model1.input, outputs = m1_layer)
m2 = Model(inputs = model2.input, outputs = m2_layer)

# feature extraction
m1_output = m1.predict(X_test1)
m2_output = m2.predict(X_test2)
X_test = np.column_stack((m1_output, m2_output)) # concatenation

model_name = '757_CNN_STFT_MFCC_SVM_EXTENDEDBALLROOM_8'
model = joblib.load(f'models/{model_name}.pkl')

preds = model.predict(X_test)
cm = confusion_matrix(y_true = Y_test1.argmax(axis = 1), y_pred = preds)
cnf_matrix(cm, EXTENDED_BALLROOM['genres'], name = model_name)
